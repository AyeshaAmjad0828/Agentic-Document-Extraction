# %%
#pip install pdfplumber PyPDF2 paddleocr python-docx docx2txt pillow opencv-python paddlepaddle PyMuPDF
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pdfplumber in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (0.11.4)
# Requirement already satisfied: PyPDF2 in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (3.0.1)
# Requirement already satisfied: paddleocr in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (2.9.1)
# Requirement already satisfied: python-docx in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (1.1.2)
# Requirement already satisfied: docx2txt in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (0.8)
# Requirement already satisfied: pillow in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (10.4.0)
# Requirement already satisfied: opencv-python in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (4.10.0.84)
# Collecting paddlepaddle
#   Downloading paddlepaddle-2.6.2-cp311-cp311-win_amd64.whl.metadata (8.8 kB)
# Requirement already satisfied: PyMuPDF in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (1.25.0)
# Requirement already satisfied: pdfminer.six==20231228 in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from pdfplumber) (20231228)
# Requirement already satisfied: pypdfium2>=4.18.0 in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from pdfplumber) (4.30.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from pdfminer.six==20231228->pdfplumber) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from pdfminer.six==20231228->pdfplumber) (43.0.3)
# Requirement already satisfied: shapely in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from paddleocr) (2.0.6)
# Requirement already satisfied: scikit-image in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from paddleocr) (0.25.0)
# Requirement already satisfied: imgaug in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from paddleocr) (0.4.0)
# Requirement already satisfied: pyclipper in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from paddleocr) (1.3.0.post6)
# Requirement already satisfied: lmdb in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from paddleocr) (1.5.1)
# Requirement already satisfied: tqdm in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from paddleocr) (4.66.5)
# Requirement already satisfied: numpy<2.0 in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from paddleocr) (1.26.4)
# Requirement already satisfied: rapidfuzz in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from paddleocr) (3.11.0)
# Requirement already satisfied: opencv-contrib-python in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from paddleocr) (4.10.0.84)
# Requirement already satisfied: cython in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from paddleocr) (3.0.11)
# Requirement already satisfied: pyyaml in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from paddleocr) (6.0.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from paddleocr) (4.12.3)
# Requirement already satisfied: fonttools>=4.24.0 in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from paddleocr) (4.53.1)
# Requirement already satisfied: fire>=0.3.0 in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from paddleocr) (0.7.0)
# Requirement already satisfied: requests in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from paddleocr) (2.32.3)
# Requirement already satisfied: albumentations==1.4.10 in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from paddleocr) (1.4.10)
# Requirement already satisfied: albucore==0.0.13 in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from paddleocr) (0.0.13)
# Requirement already satisfied: tomli>=2.0.1 in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from albucore==0.0.13->paddleocr) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.9.0 in c:\users\ayesha.amjad\appdata\roaming\python\python311\site-packages (from albucore==0.0.13->paddleocr) (4.12.2)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from albucore==0.0.13->paddleocr) (4.10.0.84)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from albumentations==1.4.10->paddleocr) (1.14.1)
# Requirement already satisfied: scikit-learn>=1.3.2 in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from albumentations==1.4.10->paddleocr) (1.5.2)
# Requirement already satisfied: pydantic>=2.7.0 in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from albumentations==1.4.10->paddleocr) (2.9.2)
# Requirement already satisfied: lxml>=3.1.0 in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from python-docx) (5.3.0)
# Requirement already satisfied: httpx in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from paddlepaddle) (0.27.2)
# Requirement already satisfied: decorator in c:\users\ayesha.amjad\appdata\roaming\python\python311\site-packages (from paddlepaddle) (5.1.1)
# Collecting astor (from paddlepaddle)
#   Using cached astor-0.8.1-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting opt-einsum==3.3.0 (from paddlepaddle)
#   Downloading opt_einsum-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting protobuf<=3.20.2,>=3.1.0 (from paddlepaddle)
#   Downloading protobuf-3.20.2-py2.py3-none-any.whl.metadata (720 bytes)
# Requirement already satisfied: termcolor in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from fire>=0.3.0->paddleocr) (2.4.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from scikit-image->paddleocr) (3.3)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from scikit-image->paddleocr) (2.36.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from scikit-image->paddleocr) (2024.12.12)
# Requirement already satisfied: packaging>=21 in c:\users\ayesha.amjad\appdata\roaming\python\python311\site-packages (from scikit-image->paddleocr) (24.1)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from scikit-image->paddleocr) (0.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4->paddleocr) (2.6)
# Requirement already satisfied: anyio in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from httpx->paddlepaddle) (4.6.0)
# Requirement already satisfied: certifi in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from httpx->paddlepaddle) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from httpx->paddlepaddle) (1.0.5)
# Requirement already satisfied: idna in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from httpx->paddlepaddle) (3.8)
# Requirement already satisfied: sniffio in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from httpx->paddlepaddle) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx->paddlepaddle) (0.14.0)
# Requirement already satisfied: six in c:\users\ayesha.amjad\appdata\roaming\python\python311\site-packages (from imgaug->paddleocr) (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from imgaug->paddleocr) (3.9.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from requests->paddleocr) (2.2.2)
# Requirement already satisfied: colorama in c:\users\ayesha.amjad\appdata\roaming\python\python311\site-packages (from tqdm->paddleocr) (0.4.6)
# Requirement already satisfied: cffi>=1.12 in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (1.17.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from pydantic>=2.7.0->albumentations==1.4.10->paddleocr) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from pydantic>=2.7.0->albumentations==1.4.10->paddleocr) (2.23.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn>=1.3.2->albumentations==1.4.10->paddleocr) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn>=1.3.2->albumentations==1.4.10->paddleocr) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->imgaug->paddleocr) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->imgaug->paddleocr) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->imgaug->paddleocr) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->imgaug->paddleocr) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ayesha.amjad\appdata\roaming\python\python311\site-packages (from matplotlib->imgaug->paddleocr) (2.9.0.post0)
# Requirement already satisfied: pycparser in c:\users\ayesha.amjad\appdata\local\programs\python\python311\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (2.22)
# Downloading paddlepaddle-2.6.2-cp311-cp311-win_amd64.whl (81.1 MB)
#    ---------------------------------------- 0.0/81.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/81.1 MB ? eta -:--:--
#    ---------------------------------------- 0.5/81.1 MB 1.3 MB/s eta 0:01:03
#    ---------------------------------------- 0.8/81.1 MB 1.3 MB/s eta 0:01:03
#    ---------------------------------------- 0.8/81.1 MB 1.3 MB/s eta 0:01:03
#     --------------------------------------- 1.0/81.1 MB 1.1 MB/s eta 0:01:14
#     --------------------------------------- 1.0/81.1 MB 1.1 MB/s eta 0:01:14
#     --------------------------------------- 1.0/81.1 MB 1.1 MB/s eta 0:01:14
#     --------------------------------------- 1.0/81.1 MB 1.1 MB/s eta 0:01:14
#     --------------------------------------- 1.0/81.1 MB 1.1 MB/s eta 0:01:14
#     --------------------------------------- 1.0/81.1 MB 1.1 MB/s eta 0:01:14
#     --------------------------------------- 1.0/81.1 MB 1.1 MB/s eta 0:01:14
#     --------------------------------------- 1
#    ---------------------------------------  79.7/81.1 MB 909.0 kB/s eta 0:00:02
#    ---------------------------------------  80.0/81.1 MB 899.0 kB/s eta 0:00:02
#    ---------------------------------------  80.0/81.1 MB 899.0 kB/s eta 0:00:02
#    ---------------------------------------  80.0/81.1 MB 899.0 kB/s eta 0:00:02
#    ---------------------------------------  80.0/81.1 MB 899.0 kB/s eta 0:00:02
#    ---------------------------------------  80.0/81.1 MB 899.0 kB/s eta 0:00:02
#    ---------------------------------------  80.2/81.1 MB 873.0 kB/s eta 0:00:02
#    ---------------------------------------  80.2/81.1 MB 873.0 kB/s eta 0:00:02
#    ---------------------------------------  80.2/81.1 MB 873.0 kB/s eta 0:00:02
#    ---------------------------------------  80.2/81.1 MB 873.0 kB/s eta 0:00:02
#    ---------------------------------------  80.2/81.1 MB 873.0 kB/s eta 0:00:02
#    ---------------------------------------  80.2/81.1 MB 873.0 kB/s eta 0:00:02
#    ---------------------------------------  80.5/81.1 MB 865.9 kB/s eta 0:00:01
#    ---------------------------------------  80.7/81.1 MB 869.8 kB/s eta 0:00:01
#    ---------------------------------------  81.0/81.1 MB 875.0 kB/s eta 0:00:01
#    ---------------------------------------- 81.1/81.1 MB 871.7 kB/s eta 0:00:00
# Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Downloading protobuf-3.20.2-py2.py3-none-any.whl (162 kB)
# Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Installing collected packages: protobuf, opt-einsum, astor, paddlepaddle
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.1
#     Uninstalling protobuf-5.29.1:
#       Successfully uninstalled protobuf-5.29.1
#   Attempting uninstall: opt-einsum
#     Found existing installation: opt_einsum 3.4.0
#     Uninstalling opt_einsum-3.4.0:
#       Successfully uninstalled opt_einsum-3.4.0
# Successfully installed astor-0.8.1 opt-einsum-3.3.0 paddlepaddle-2.6.2 protobuf-3.20.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opentelemetry-proto 1.29.0 requires protobuf<6.0,>=5.0, but you have protobuf 3.20.2 which is incompatible.
# tensorflow-intel 2.17.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 3.20.2 which is incompatible.

# %%
import os
import numpy as np
from typing import Text, List, Dict, Union
from pathlib import Path
import json

# PDF processing
import pdfplumber
import PyPDF2
from paddleocr import PaddleOCR
import fitz  # PyMuPDF

# Document processing
from docx import Document
import docx2txt

# Image processing
from PIL import Image
import cv2
import io
import base64

# %% [markdown]
# ### Document Reader (Reads from pdf, scanned pdf, txt, doc, docx, .png, .jpg, .jpeg, .tiff, .bmp)

# %%
class DocumentReader:
    def __init__(self):
        self.ocr = PaddleOCR(use_angle_cls=True, lang='en')
        
    def read_document(self, file_path: str) -> Dict[str, Union[str, List[str]]]:
        """
        Read document and process each page exactly once
        
        Args:
            file_path (str): Path to the document
            
        Returns:
            dict: Contains 'text' (full document text), 'pages' (list of page texts), 
                and 'num_pages' (total pages)
        """
        file_extension = Path(file_path).suffix.lower()
        
        try:
            # First, determine if it's a PDF and what type
            if file_extension == '.pdf':
                # Try to open with pdfplumber first to check if searchable
                with pdfplumber.open(file_path) as pdf:
                    # Check first page for text
                    first_page = pdf.pages[0]
                    test_text = first_page.extract_text()
                    
                    if test_text and test_text.strip():
                        print("Processing as searchable PDF...")
                        return self.read_searchable_pdf(file_path)
                    else:
                        print("Processing as scanned PDF...")
                        return self.read_scanned_pdf(file_path)
                        
            elif file_extension in ['.doc', '.docx']:
                print("Processing as Word document...")
                return self.read_document_file(file_path)
                
            else:
                raise ValueError(f"Unsupported file format: {file_extension}")
                
        except Exception as e:
            raise Exception(f"Error processing {file_path}: {str(e)}")

    def read_searchable_pdf(self, file_path: str) -> Dict[str, Union[str, List[str]]]:
        """Extract text from searchable PDFs while preserving layout and pages"""
        try:
            pages_text = []
            full_text = []
            
            with pdfplumber.open(file_path) as pdf:
                for page in pdf.pages:
                    # Extract tables first
                    tables = page.extract_tables()
                    tables_text = []
                    
                    for table in tables:
                        table_rows = []
                        for row in table:
                            # Clean and align row data
                            cleaned_row = [str(cell).strip() if cell else '' for cell in row]
                            table_rows.append('\t'.join(cleaned_row))
                        tables_text.append('\n'.join(table_rows))
                    
                    # Extract regular text with layout preservation
                    text = page.extract_text(
                        x_tolerance=5,
                        y_tolerance=5,
                        layout=True,
                        preserve_blank_chars=True
                    )
                    
                    # Combine tables and text while preserving structure
                    page_content = []
                    if text:
                        page_content.append(text)
                    if tables_text:
                        page_content.extend(tables_text)
                    
                    formatted_page = '\n\n'.join(page_content)
                    pages_text.append(formatted_page)
                    full_text.append(formatted_page)
                
                return {
                    'text': '\n\n'.join(filter(None, full_text)),
                    'pages': pages_text,
                    'num_pages': len(pages_text),
                    'layout_preserved': True
                }
                
        except Exception as e:
            print(f"pdfplumber failed: {e}, trying PyPDF2")
            try:
                pages_text = []
                full_text = []
                
                # Try PyMuPDF (fitz) for better layout preservation
                doc = fitz.open(file_path)
                for page in doc:
                    # Get text blocks with position information
                    blocks = page.get_text("blocks")
                    # Sort blocks by vertical position, then horizontal
                    blocks.sort(key=lambda b: (b[1], b[0]))
                    
                    page_text = []
                    current_y = None
                    current_line = []
                    
                    for b in blocks:
                        if current_y is None:
                            current_y = b[1]
                        
                        # If significant vertical change, start new line
                        if abs(b[1] - current_y) > 5:  # Adjust threshold as needed
                            if current_line:
                                page_text.append(' '.join(current_line))
                            current_line = []
                            current_y = b[1]
                        
                        current_line.append(b[4])
                    
                    # Add last line if exists
                    if current_line:
                        page_text.append(' '.join(current_line))
                    
                    formatted_page = '\n'.join(page_text)
                    pages_text.append(formatted_page)
                    full_text.append(formatted_page)
                
                return {
                    'text': '\n\n'.join(filter(None, full_text)),
                    'pages': pages_text,
                    'num_pages': len(pages_text),
                    'layout_preserved': True
                }
                
            except Exception as e2:
                raise Exception(f"Both PDF readers failed: {e2}")

    def read_scanned_pdf(self, file_path: str) -> Dict[str, Union[str, List[str]]]:
        """Extract text from scanned PDFs using OCR, preserving layout"""
        try:
            pdf_document = fitz.open(file_path)
            num_pages = len(pdf_document)
            print(f"Total pages detected: {num_pages}")
            
            pages_text = []
            
            for page_num in range(num_pages):
                print(f"Processing page {page_num + 1}/{num_pages} with OCR")
                page = pdf_document[page_num]
                pix = page.get_pixmap()
                
                # Convert pixmap to image
                img = Image.frombytes("RGB", [pix.width, pix.height], pix.samples)
                img_cv = cv2.cvtColor(np.array(img), cv2.COLOR_RGB2BGR)
                
                # Perform OCR with layout analysis
                result = self.ocr.ocr(img_cv, cls=True)
                
                if result:
                    # Create a grid to maintain spatial relationships
                    page_height = img_cv.shape[0]
                    page_width = img_cv.shape[1]
                    
                    # Extract text blocks with position information
                    blocks = []
                    for line in result:
                        if line:
                            for word in line:
                                ((x1, y1), (x2, y2), (x3, y3), (x4, y4)), (text, conf) = word
                                
                                # Calculate center position and width
                                center_x = (min(x1, x2, x3, x4) + max(x1, x2, x3, x4)) / 2
                                center_y = (min(y1, y2, y3, y4) + max(y1, y2, y3, y4)) / 2
                                width = max(x1, x2, x3, x4) - min(x1, x2, x3, x4)
                                
                                blocks.append({
                                    'text': text,
                                    'x': center_x,
                                    'y': center_y,
                                    'width': width,
                                    'original_coords': ((x1, y1), (x2, y2), (x3, y3), (x4, y4))
                                })
                    
                    # Sort blocks by vertical position first
                    blocks.sort(key=lambda b: b['y'])
                    
                    # Group blocks into lines based on y-position
                    lines = []
                    current_line = []
                    current_y = None
                    y_threshold = page_height * 0.005  # Adjust threshold based on page height
                    
                    for block in blocks:
                        if current_y is None:
                            current_y = block['y']
                            current_line.append(block)
                        elif abs(block['y'] - current_y) <= y_threshold:
                            current_line.append(block)
                        else:
                            # Sort current line by x-position
                            current_line.sort(key=lambda b: b['x'])
                            
                            # Calculate spacing between blocks
                            formatted_line = []
                            last_x = 0
                            for b in current_line:
                                # Add appropriate spacing
                                spaces = int((b['x'] - last_x) / (page_width * 0.0075))  # Adjust divisor for spacing
                                formatted_line.append(" " * spaces + b['text'])
                                last_x = b['x'] + b['width']
                            
                            lines.append("".join(formatted_line))
                            current_line = [block]
                            current_y = block['y']
                    
                    # Process last line
                    if current_line:
                        current_line.sort(key=lambda b: b['x'])
                        formatted_line = []
                        last_x = 0
                        for b in current_line:
                            spaces = int((b['x'] - last_x) / (page_width * 0.02))
                            formatted_line.append(" " * spaces + b['text'])
                            last_x = b['x'] + b['width']
                        lines.append("".join(formatted_line))
                    
                    # Join lines with appropriate vertical spacing
                    page_text = "\n".join(lines)
                else:
                    page_text = ""
                
                pages_text.append(page_text)
            
            return {
                'text': '\n\n'.join(filter(None, pages_text)),
                'pages': pages_text,
                'num_pages': num_pages,
                'layout_preserved': True
            }
            
        except Exception as e:
            raise Exception(f"OCR processing failed: {e}")

    def read_document_file(self, file_path: str) -> Dict[str, Union[str, List[str]]]:
        """Extract text from DOC/DOCX files while preserving sections"""
        try:
            doc = Document(file_path)
            pages_text = []
            current_page = []
            paragraph_count = 0
            paragraphs_per_page = 10  # Adjust this value based on your needs
            
            # Process paragraphs
            for para in doc.paragraphs:
                if para.text.strip():
                    current_page.append(para.text)
                    paragraph_count += 1
                    
                    # Start new page after certain number of paragraphs
                    if paragraph_count >= paragraphs_per_page:
                        pages_text.append('\n'.join(current_page))
                        current_page = []
                        paragraph_count = 0
            
            # Add remaining paragraphs as last page
            if current_page:
                pages_text.append('\n'.join(current_page))
            
            return {
                'text': '\n'.join(pages_text),
                'pages': pages_text,
                'num_pages': len(pages_text)
            }
            
        except Exception as e:
            raise Exception(f"Document processing failed: {e}")
        
        
    
    def read_image(self, file_path: str) -> Dict[str, Union[str, List[str]]]:
        """
        Extract text from images using PaddleOCR with layout preservation.
        Supports formats: PNG, JPG, JPEG, TIFF, BMP
        """
        supported_formats = ['.png', '.jpg', '.jpeg', '.tiff', '.bmp']
        file_extension = Path(file_path).suffix.lower()
        
        if file_extension not in supported_formats:
            raise ValueError(f"Unsupported image format: {file_extension}")
        
        try:
            print(f"Processing image: {file_path}")
            
            # Read image
            if file_extension == '.tiff':
                image = Image.open(file_path)
                if image.mode != 'RGB':
                    image = image.convert('RGB')
                image = np.array(image)
                image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
            else:
                image = cv2.imread(file_path)
                if image is None:
                    raise ValueError(f"Failed to read image: {file_path}")
            
            # Get image dimensions
            height, width = image.shape[:2]
            
            # Perform OCR
            result = self.ocr.ocr(image, cls=True)
            
            if not result:
                return {
                    'text': '',
                    'pages': [''],
                    'num_pages': 1,
                    'layout_preserved': True
                }
            
            # Process OCR results with layout preservation
            blocks = []
            for line in result:
                if line:
                    for word in line:
                        ((x1, y1), (x2, y2), (x3, y3), (x4, y4)), (text, conf) = word
                        
                        # Calculate center position and dimensions
                        center_x = (min(x1, x2, x3, x4) + max(x1, x2, x3, x4)) / 2
                        center_y = (min(y1, y2, y3, y4) + max(y1, y2, y3, y4)) / 2
                        block_width = max(x1, x2, x3, x4) - min(x1, x2, x3, x4)
                        
                        blocks.append({
                            'text': text,
                            'x': center_x,
                            'y': center_y,
                            'width': block_width,
                            'confidence': conf
                        })
            
            # Sort blocks by vertical position
            blocks.sort(key=lambda b: b['y'])
            
            # Group blocks into lines with adaptive thresholding
            lines = []
            current_line = []
            current_y = None
            y_threshold = height * 0.015  # Adaptive threshold based on image height
            
            for block in blocks:
                if current_y is None:
                    current_y = block['y']
                    current_line.append(block)
                elif abs(block['y'] - current_y) <= y_threshold:
                    current_line.append(block)
                else:
                    # Process current line
                    if current_line:
                        # Sort blocks in line by x-position
                        current_line.sort(key=lambda b: b['x'])
                        
                        # Calculate horizontal spacing
                        formatted_line = []
                        last_x = 0
                        min_space_width = width * 0.01  # Minimum space width
                        
                        for b in current_line:
                            # Calculate number of spaces needed
                            if last_x > 0:
                                space_count = max(1, int((b['x'] - last_x) / min_space_width))
                                formatted_line.append(" " * space_count)
                            
                            formatted_line.append(b['text'])
                            last_x = b['x'] + b['width']
                        
                        lines.append("".join(formatted_line))
                    
                    # Start new line
                    current_line = [block]
                    current_y = block['y']
            
            # Process last line
            if current_line:
                current_line.sort(key=lambda b: b['x'])
                formatted_line = []
                last_x = 0
                for b in current_line:
                    if last_x > 0:
                        space_count = max(1, int((b['x'] - last_x) / min_space_width))
                        formatted_line.append(" " * space_count)
                    formatted_line.append(b['text'])
                    last_x = b['x'] + b['width']
                lines.append("".join(formatted_line))
            
            # Add appropriate vertical spacing between lines
            formatted_text = ""
            last_y = 0
            for i, line in enumerate(lines):
                if i > 0:
                    # Calculate vertical spacing
                    current_y = blocks[i]['y']
                    line_spacing = int((current_y - last_y) / (height * 0.02))
                    formatted_text += "\n" * max(1, line_spacing)
                formatted_text += line
                last_y = blocks[i]['y']
            
            return {
                'text': formatted_text,
                'pages': [formatted_text],
                'num_pages': 1,
                'layout_preserved': True,
                'confidence_scores': [block['confidence'] for block in blocks]
            }
            
        except Exception as e:
            raise Exception(f"Error processing image {file_path}: {str(e)}")

    @staticmethod
    def is_image_file(file_path: str) -> bool:
        """Check if file is a supported image format"""
        supported_formats = ['.png', '.jpg', '.jpeg', '.tiff', '.bmp']
        return Path(file_path).suffix.lower() in supported_formats
    

    def convert_image_to_pdf(self, image_path: str, output_pdf_path: str = None) -> str:
        """
        Convert image to PDF format
        
        Args:
            image_path: Path to source image
            output_pdf_path: Optional path for output PDF. If None, uses same name as image
            
        Returns:
            str: Path to created PDF file
        """
        try:
            # If output path not specified, create one
            if output_pdf_path is None:
                output_pdf_path = str(Path(image_path).with_suffix('.pdf'))
                
            # Open image
            image = Image.open(image_path)
            
            # Convert to RGB if necessary
            if image.mode != 'RGB':
                image = image.convert('RGB')
                
            # Save as PDF
            image.save(output_pdf_path, 'PDF', resolution=300.0)
            
            return output_pdf_path
            
        except Exception as e:
            raise Exception(f"Error converting image to PDF: {str(e)}")

    def read_image_as_pdf(self, image_path: str) -> Dict[str, Union[str, List[str]]]:
        """
        Read image by first converting to PDF and then using scanned PDF processing
        
        Args:
            image_path: Path to image file
            
        Returns:
            dict: Contains extracted text with layout information
        """
        try:
            # Convert image to PDF
            pdf_path = self.convert_image_to_pdf(image_path)
            
            # Process using scanned PDF function
            result = self.read_scanned_pdf(pdf_path)
            
            # Clean up temporary PDF
            if Path(pdf_path).exists():
                Path(pdf_path).unlink()
                
            return result
            
        except Exception as e:
            raise Exception(f"Error processing image as PDF: {str(e)}")

# %%
reader = DocumentReader()
pdf_path=r'C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\test\filesforprocessing\Invoice S4160821262.pdf'
result = reader.read_document(pdf_path)

# Print processing results
print(f"\nProcessed {result['num_pages']} pages")
for i, page in enumerate(result['pages'], 1):
    print(f"\nPage {i}:")
    print(page)

# Get number of pages
print(f"Total pages: {result['num_pages']}")
# Out:
# [2025/01/03 19:20:03] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\ayesha.amjad/.paddleocr/whl\\det\\en\\en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\ayesha.amjad/.paddleocr/whl\\rec\\en\\en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='c:\\Users\\ayesha.amjad\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\paddleocr\\ppocr\\utils\\en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='C:\\Users\\ayesha.amjad/.paddleocr/whl\\cls\\ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# Processing as searchable PDF...
#
# Processed 2 pages
#
# Page 1:
#
#
#
#        Invoice Number
#
#        S4160821262
#
#       ATTN Metcash - THE FRESH  PANTRY  - BONDI
#
#       48 Hall Street
#       BONDI BEACH NSW 2026
#       PH - 02 9741 3000
#
#
#                                           Invoice Date  Big Mouth Foods Pty Ltd
#                                           16 Aug 2021   ABN 94 601 150 501
#                                                         PO BOX 2182
#       TAX   INVOICE                       Customer PO Number ROSE BAY NORTH NSW 2030
#                                                         AUSTRALIA
#                                           16461
#                                                         Email: accounts@bigmouthfoods.com.au
#        *  bii/Wich                                      General Enquiries: 02 9699 8654
#                                                         Bank Details: ANZ
#                                                         BIG MOUTH FOODS PTY LTD
#                                                         BSB: 012-396 A/C : 3921-29224
#      Description                             QTY  Unit Price    GST  Amount AUD
#      -------------(LARGE) MUNCH BOX------------ 1 0.00                    0.00
#      BMF-MBLCHTE, MUNCH BOX ((LARGE)) - TERIYAKI CHICKEN 1 5.50 10%       5.50
#      BMF-MBLTUNA, MUNCH BOX ((LARGE)) TUNA   1   5.50           10%       5.50
#      BMF-MBLCHSC, MUNCH BOX ((LARGE)) - CHICKEN SCHNITZEL 1 5.50 10%      5.50
#      -------------MEDIUM MUNCH BOX------------ 1 0.00                     0.00
#      BMF-MBMTUNA, MUNCH BOX (Medium) - Tuna  1   3.50           10%       3.50
#
#      -------------RICE PAPER ROLL------------ 1  0.00                     0.00
#      BMF-VRPRCHI, RICE PAPER ROLL - CHICKEN TWINPACK 1 4.50     10%       4.50
#
#      BMF-VRPRPRA, RICE PAPER ROLL - PRAWN TWINPACK 1 5.00       10%       5.00
#      -------------BIG CRUNCH ROLLS------------- 1 0.00                    0.00
#      BMF-CHTCU01, BIG CRUNCH SUSHI: CHICKEN TERIYAKI - CUCUMBER 1 2.20 10% 2.20
#
#      BMF-TUNCU01, BIG CRUNCH SUSHI: TUNA - CUCUMBER 2 2.20      10%       4.40
#      ---------SALADS----------               1   0.00                     0.00
#      BMF-ACHBWLS, Sml Salad - Vietnam        1   5.00           10%       5.00
#
#      BMF-SALBWLS, Sml Poke- Salmon           1   5.00           10%       5.00
#      BMF-TSLSLDL, LG SALAD - WASABI SALMON   1   6.50           10%       6.50
#      ------RETAIL MEALS AND SOUPS-------     1   0.00                     0.00
#
#      BMF-RETTRCH, RETAIL- T CHICKEN          1   6.50           10%       6.50
#      ---MAKI TWINPACKS----                   1   0.00                     0.00
#
#      BMF-MAKSAL2PK, 2 PK MAKI - SALMON       1   4.60           10%       4.60
#
#                                                               Subtotal    63.70
#
#
#
#           ABN: 94 601 150 501. Registered Office: PO BOX 2182, Rose Bay North, NSW, 2030, Australia
#           Subject to our standard Terms & Conditions of Supply, which appear on our website www.bigcrunchsushi.com. No claims are
#           recognised unless made on the same day of delivery. All supplied products must be stored below 5 degrees Celsius.
#
# Page 2:
#
#
#
#
#                                                            Total GST 10%  6.37
#                                                          Invoice Total AUD 70.07
#                                                       Total Net Payments AUD 0.00
#
#                                                          Amount Due AUD   70.07
#
#           Thank you for your order. We appreciate your business and your prompt payment as per agreed payment terms:
#           27 Aug 2021
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           abn: 94 601 150 501. Registered Office: PO BOX 2182, Rose Bay North, NSW, 2030, Australia
#
# Total pages: 2

# %%
reader = DocumentReader()
pdf_path=r'C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\test\scanned\scan.pdf'
result = reader.read_document(pdf_path)

# Print processing results
print(f"\nProcessed {result['num_pages']} pages")
for i, page in enumerate(result['pages'], 1):
    print(f"\nPage {i}:")
    print(page)

# Get number of pages
print(f"Total pages: {result['num_pages']}")
# Out:
# [2025/01/03 19:20:15] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\ayesha.amjad/.paddleocr/whl\\det\\en\\en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\ayesha.amjad/.paddleocr/whl\\rec\\en\\en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='c:\\Users\\ayesha.amjad\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\paddleocr\\ppocr\\utils\\en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='C:\\Users\\ayesha.amjad/.paddleocr/whl\\cls\\ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# Processing as scanned PDF...
# Total pages detected: 1
# Processing page 1/1 with OCR
# [2025/01/03 19:20:17] ppocr DEBUG: dt_boxes num : 57, elapsed : 0.35111379623413086
# [2025/01/03 19:20:17] ppocr DEBUG: cls num  : 57, elapsed : 0.13310027122497559
# [2025/01/03 19:20:19] ppocr DEBUG: rec_res num  : 57, elapsed : 2.5036306381225586
#
# Processed 1 pages
#
# Page 1:
#                                                                                                                          POBOX72
#                                                                     Fresh Selections Pty LtdNORTHGATE Q4013
#                                                                                                        TELEPHONE: (07) 3278 3065 - 7.30am to 3.30pm Mon  Fd
#                  A.B.N. 86-082-768-830                                from litte things BIG THINGS GROW
#                                                                                                                 (07)3256 6399 - A/Hours & W/ends
#                                                                                                                    FACSIMILE: (07) 3260 6910
#                                           TAXINVOICE161758
#                 Invoice To
#                                   THORNLANDS IGA
#                                  REDLAND BAY&
#                                     ISLAND LOOKOUT RD
#                                      THORNLANDS QLD4164
#                Phone       0738213665
#                                                                                    Invoice Date      Account Code
#                                                                                                                       Page
#                                                                                    01-SEP-21       THORN
#                                                                                                                       10f1
#                   Reference: FREIGHT
#                         Description
#                                                                     Order     Supply      Unit
#                                                                                                          Price       Total
#                         FREIGHT(*
#                                                                                                              45.00      45.00
#                                                                          Jones Rtaj Group
#                                                       Date recd/chdkerd
#                                                                                   oua
#                                                        Temp check c
#                                                      Claim or cre
#                                                                                    Dit
#                                                     Received by
#                                                                             Ma
#                                                        Date entered FOS
#                                                     Department
#                                                    Entered by                    ixed
#                          CREDITS MUST BE CLAIMED WITHIN
#                           24 HOURS OF STOCK BEING RECEIVED
#                      )INDICATES TAXABLE ITEM                  Terms:7 days                GST       4.50
#                                                                                                      Invoice Total  49.50
#   IC_PRT_POF
# Total pages: 1

# %%
reader = DocumentReader()

path=r'C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\compare\FlipkartInvoice.png'
# Process single image
try:
    result = reader.read_image(path)
    print(f"Extracted Text:\n{result['text']}")
    print(f"Average Confidence: {sum(result['confidence_scores'])/len(result['confidence_scores']):.2f}")
except Exception as e:
    print(f"Error: {e}")
# Out:
# [2025/01/03 19:21:16] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\ayesha.amjad/.paddleocr/whl\\det\\en\\en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\ayesha.amjad/.paddleocr/whl\\rec\\en\\en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='c:\\Users\\ayesha.amjad\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\paddleocr\\ppocr\\utils\\en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='C:\\Users\\ayesha.amjad/.paddleocr/whl\\cls\\ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\compare\FlipkartInvoice.png
# [2025/01/03 19:21:17] ppocr DEBUG: dt_boxes num : 56, elapsed : 0.3717923164367676
# [2025/01/03 19:21:17] ppocr DEBUG: cls num  : 56, elapsed : 0.14728188514709473
# [2025/01/03 19:21:22] ppocr DEBUG: rec_res num  : 56, elapsed : 4.479409217834473
# Extracted Text:
# Retail Invoices/Bill
#
#  Invoice No : # BLR_WFLD20151000982590
# Sold By : WS Retail Services Pvt. Ltd.,.
# Warehouse Address: NO. 42/I & 43, KACHERAKANAHALLI VILLAGE, JADIGENAHALLI HOBLI, HOSKOTE TALUK, Bangalore, Karnataka, India - S60067
#
# Order ID: OD304175096047380001 Billing Address.                Shipping Address
# Anushrut Singh               Anushrut Singh
# Order Date: 15-10-2015             3/64, Vishwas Khand,Gomti Nagar.,.  3/64, Vishwas Khand,Gomti Nagar.,.
# *Keep this invoice and
# Invoice Date: 20-10-2015           near Fun republic mall and nehru    near Fun republic mall and nehru manufacturer box for
# VAT/TIN: 29670869006     enclave.                     enclave.                          warranty purposes.
# Lucknow 226010 Uttar Pradesh     Lucknow 226010 Uttar Pradesh
# Service tax #: AAACW8725FSD001 Phone: 8756390642            Phone: 8756390642
# Product          Title                                  Qty   Price()  Tax(%)  Tax(  Total()
#  Memory cards                  SanDisk Ultra 16 GB MicroSDHC Class 1      278.61   14.50%   40.39    319.00
# FSN:                     10 48 MB/s Memory Card                              CST
# ACCEA5E3GPBQJ9P9         Price is inclusive of Promotional Discount of Rs -40.00
# WID: VM72516
# Total 1     278.61           40.39   319.00
# Grand Total      319.00
# *This is a computer generated invoice.                   WS Retail Services Pvt. Ltd :
# (Authorized Signalory).
# Average Confidence: 0.99

# %%
reader = DocumentReader()
path=r'C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\compare\FlipkartInvoice.png'

# Process single image through PDF conversion
try:
    image_path = path
    result = reader.read_image_as_pdf(image_path)
    print(f"\nExtracted Text:")
    print(result['text'])
except Exception as e:
    print(f"Error: {e}")
# Out:
# [2025/01/03 19:20:50] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\ayesha.amjad/.paddleocr/whl\\det\\en\\en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\ayesha.amjad/.paddleocr/whl\\rec\\en\\en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='c:\\Users\\ayesha.amjad\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\paddleocr\\ppocr\\utils\\en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='C:\\Users\\ayesha.amjad/.paddleocr/whl\\cls\\ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# Total pages detected: 1
# Processing page 1/1 with OCR
# [2025/01/03 19:20:51] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.10057950019836426
# [2025/01/03 19:20:51] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2025/01/03 19:20:51] ppocr DEBUG: rec_res num  : 0, elapsed : 0.0
#
# Extracted Text:

# %%
def process_images_in_folder(folder_path: str, output_dir: str = None) -> List[Dict]:
    """
    Process images in a folder and save extracted text to files
    
    Args:
        folder_path: Path to folder containing images
        output_dir: Directory to save text files (defaults to 'extracted_text' in folder_path)
    """
    # Set up output directory
    if output_dir is None:
        output_dir = os.path.join(folder_path, 'extracted_text')
    os.makedirs(output_dir, exist_ok=True)
    
    results = []
    for file in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file)
        # Call the static method on the class instead of the instance
        if DocumentReader.is_image_file(file_path):  # Changed this line
            try:
                # Process image
                result = reader.read_image(file_path)
                
                # Create output filename (same name but .txt extension)
                output_filename = os.path.splitext(file)[0] + '.txt'
                output_path = os.path.join(output_dir, output_filename)
                
                # Save extracted text to file
                with open(output_path, 'w', encoding='utf-8') as f:
                    f.write(result['text'])
                
                results.append({
                    'file': file,
                    'text': result['text'],
                    'confidence': sum(result['confidence_scores'])/len(result['confidence_scores']),
                    'output_path': output_path
                })
                print(f"Processed {file} -> {output_filename}")
                
            except Exception as e:
                print(f"Error processing {file}: {e}")
    return results

# Example usage
folder_results = process_images_in_folder(r'C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip')
for result in folder_results:
    print(f"\nFile: {result['file']}")
    print(f"Confidence: {result['confidence']:.2f}")
    print(f"Saved to: {result['output_path']}")
# Out:
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\1.jpg
# [2025/01/03 20:14:46] ppocr DEBUG: dt_boxes num : 37, elapsed : 0.5219271183013916
# [2025/01/03 20:14:47] ppocr DEBUG: cls num  : 37, elapsed : 0.37043070793151855
# [2025/01/03 20:14:49] ppocr DEBUG: rec_res num  : 37, elapsed : 2.5609843730926514
# Processed 1.jpg -> 1.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\10.jpg
# [2025/01/03 20:14:50] ppocr DEBUG: dt_boxes num : 42, elapsed : 0.4865250587463379
# [2025/01/03 20:14:50] ppocr DEBUG: cls num  : 42, elapsed : 0.13048744201660156
# [2025/01/03 20:14:52] ppocr DEBUG: rec_res num  : 42, elapsed : 2.531501054763794
# Processed 10.jpg -> 10.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\100.jpg
# [2025/01/03 20:14:53] ppocr DEBUG: dt_boxes num : 45, elapsed : 0.5492081642150879
# [2025/01/03 20:14:53] ppocr DEBUG: cls num  : 45, elapsed : 0.269946813583374
# [2025/01/03 20:14:56] ppocr DEBUG: rec_res num  : 45, elapsed : 3.2858242988586426
# Processed 100.jpg -> 100.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\101.jpg
# [2025/01/03 20:14:57] ppocr DEBUG: dt_boxes num : 15, elapsed : 0.3245394229888916
# [2025/01/03 20:14:57] ppocr DEBUG: cls num  : 15, elapsed : 0.17083740234375
# [2025/01/03 20:14:58] ppocr DEBUG: rec_res num  : 15, elapsed : 1.1245651245117188
# Processed 101.jpg -> 101.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\102.jpg
# [2025/01/03 20:14:59] ppocr DEBUG: dt_boxes num : 70, elapsed : 0.49284791946411133
# [2025/01/03 20:14:59] ppocr DEBUG: cls num  : 70, elapsed : 0.45130372047424316
# [2025/01/03 20:15:05] ppocr DEBUG: rec_res num  : 70, elapsed : 5.489439964294434
# Processed 102.jpg -> 102.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\11.jpg
# [2025/01/03 20:15:05] ppocr DEBUG: dt_boxes num : 43, elapsed : 0.4964711666107178
# [2025/01/03 20:15:05] ppocr DEBUG: cls num  : 43, elapsed : 0.2671523094177246
# [2025/01/03 20:15:09] ppocr DEBUG: rec_res num  : 43, elapsed : 3.4369516372680664
# Processed 11.jpg -> 11.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\12.jpg
# [2025/01/03 20:15:09] ppocr DEBUG: dt_boxes num : 167, elapsed : 0.4943716526031494
# [2025/01/03 20:15:10] ppocr DEBUG: cls num  : 167, elapsed : 0.994232177734375
# [2025/01/03 20:15:21] ppocr DEBUG: rec_res num  : 167, elapsed : 10.214797735214233
# Processed 12.jpg -> 12.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\13.jpg
# [2025/01/03 20:15:22] ppocr DEBUG: dt_boxes num : 35, elapsed : 0.18655657768249512
# [2025/01/03 20:15:22] ppocr DEBUG: cls num  : 35, elapsed : 0.08345413208007812
# [2025/01/03 20:15:24] ppocr DEBUG: rec_res num  : 35, elapsed : 1.954897403717041
# Processed 13.jpg -> 13.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\14.jpg
# [2025/01/03 20:15:25] ppocr DEBUG: dt_boxes num : 102, elapsed : 0.5292482376098633
# [2025/01/03 20:15:25] ppocr DEBUG: cls num  : 102, elapsed : 0.3523890972137451
# [2025/01/03 20:15:33] ppocr DEBUG: rec_res num  : 102, elapsed : 7.616250038146973
# Processed 14.jpg -> 14.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\15.jpg
# [2025/01/03 20:15:33] ppocr DEBUG: dt_boxes num : 67, elapsed : 0.38074636459350586
# [2025/01/03 20:15:34] ppocr DEBUG: cls num  : 67, elapsed : 0.46146559715270996
# [2025/01/03 20:15:39] ppocr DEBUG: rec_res num  : 67, elapsed : 5.452646970748901
# Processed 15.jpg -> 15.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\16.jpg
# [2025/01/03 20:15:40] ppocr DEBUG: dt_boxes num : 95, elapsed : 0.8401591777801514
# [2025/01/03 20:15:40] ppocr DEBUG: cls num  : 95, elapsed : 0.40041661262512207
# [2025/01/03 20:15:48] ppocr DEBUG: rec_res num  : 95, elapsed : 7.042158603668213
# Processed 16.jpg -> 16.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\18.jpg
# [2025/01/03 20:15:48] ppocr DEBUG: dt_boxes num : 29, elapsed : 0.4782843589782715
# [2025/01/03 20:15:48] ppocr DEBUG: cls num  : 29, elapsed : 0.19814586639404297
# [2025/01/03 20:15:50] ppocr DEBUG: rec_res num  : 29, elapsed : 2.1628382205963135
# Processed 18.jpg -> 18.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\19.jpg
# [2025/01/03 20:15:51] ppocr DEBUG: dt_boxes num : 26, elapsed : 0.800586462020874
# [2025/01/03 20:15:52] ppocr DEBUG: cls num  : 26, elapsed : 0.4775543212890625
# [2025/01/03 20:15:56] ppocr DEBUG: rec_res num  : 26, elapsed : 3.841824769973755
# Processed 19.jpg -> 19.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\2.jpg
# [2025/01/03 20:15:56] ppocr DEBUG: dt_boxes num : 58, elapsed : 0.6037502288818359
# [2025/01/03 20:15:57] ppocr DEBUG: cls num  : 58, elapsed : 0.3167712688446045
# [2025/01/03 20:16:02] ppocr DEBUG: rec_res num  : 58, elapsed : 5.31734561920166
# Processed 2.jpg -> 2.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\20.jpg
# [2025/01/03 20:16:02] ppocr DEBUG: dt_boxes num : 30, elapsed : 0.3903641700744629
# [2025/01/03 20:16:02] ppocr DEBUG: cls num  : 30, elapsed : 0.18143343925476074
# [2025/01/03 20:16:06] ppocr DEBUG: rec_res num  : 30, elapsed : 3.0658555030822754
# Processed 20.jpg -> 20.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\21.jpg
# [2025/01/03 20:16:07] ppocr DEBUG: dt_boxes num : 43, elapsed : 1.314532995223999
# [2025/01/03 20:16:08] ppocr DEBUG: cls num  : 43, elapsed : 1.026440143585205
# [2025/01/03 20:16:12] ppocr DEBUG: rec_res num  : 43, elapsed : 4.225774526596069
# Processed 21.jpg -> 21.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\22.jpg
# [2025/01/03 20:16:13] ppocr DEBUG: dt_boxes num : 73, elapsed : 0.8129715919494629
# [2025/01/03 20:16:13] ppocr DEBUG: cls num  : 73, elapsed : 0.3600902557373047
# [2025/01/03 20:16:20] ppocr DEBUG: rec_res num  : 73, elapsed : 6.373810291290283
# Processed 22.jpg -> 22.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\23.jpg
# Error processing 23.jpg: Error processing image C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\23.jpg: Failed to read image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\23.jpg
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\24.jpg
# [2025/01/03 20:16:21] ppocr DEBUG: dt_boxes num : 35, elapsed : 0.7240521907806396
# [2025/01/03 20:16:21] ppocr DEBUG: cls num  : 35, elapsed : 0.39216017723083496
# [2025/01/03 20:16:24] ppocr DEBUG: rec_res num  : 35, elapsed : 3.2358241081237793
# Processed 24.jpg -> 24.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\25.jpg
# [2025/01/03 20:16:25] ppocr DEBUG: dt_boxes num : 73, elapsed : 0.8528692722320557
# [2025/01/03 20:16:25] ppocr DEBUG: cls num  : 73, elapsed : 0.3413352966308594
# [2025/01/03 20:16:31] ppocr DEBUG: rec_res num  : 73, elapsed : 6.071134567260742
# Processed 25.jpg -> 25.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\26.jpg
# [2025/01/03 20:16:32] ppocr DEBUG: dt_boxes num : 122, elapsed : 0.3963749408721924
# [2025/01/03 20:16:33] ppocr DEBUG: cls num  : 122, elapsed : 0.7540478706359863
# [2025/01/03 20:16:43] ppocr DEBUG: rec_res num  : 122, elapsed : 10.450097560882568
# Processed 26.jpg -> 26.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\27.jpg
# [2025/01/03 20:16:44] ppocr DEBUG: dt_boxes num : 42, elapsed : 0.7198224067687988
# [2025/01/03 20:16:44] ppocr DEBUG: cls num  : 42, elapsed : 0.12845373153686523
# [2025/01/03 20:16:48] ppocr DEBUG: rec_res num  : 42, elapsed : 4.121511697769165
# Processed 27.jpg -> 27.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\28.jpg
# [2025/01/03 20:16:49] ppocr DEBUG: dt_boxes num : 47, elapsed : 0.7441158294677734
# [2025/01/03 20:16:49] ppocr DEBUG: cls num  : 47, elapsed : 0.40131068229675293
# [2025/01/03 20:16:55] ppocr DEBUG: rec_res num  : 47, elapsed : 5.260500907897949
# Processed 28.jpg -> 28.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\29.jpg
# [2025/01/03 20:16:56] ppocr DEBUG: dt_boxes num : 42, elapsed : 1.0362799167633057
# [2025/01/03 20:16:56] ppocr DEBUG: cls num  : 42, elapsed : 0.2608346939086914
# [2025/01/03 20:17:01] ppocr DEBUG: rec_res num  : 42, elapsed : 4.950821161270142
# Processed 29.jpg -> 29.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\30.jpg
# [2025/01/03 20:17:01] ppocr DEBUG: dt_boxes num : 31, elapsed : 0.51593017578125
# [2025/01/03 20:17:02] ppocr DEBUG: cls num  : 31, elapsed : 0.41621851921081543
# [2025/01/03 20:17:05] ppocr DEBUG: rec_res num  : 31, elapsed : 2.93629789352417
# Processed 30.jpg -> 30.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\31.jpg
# [2025/01/03 20:17:06] ppocr DEBUG: dt_boxes num : 39, elapsed : 0.7285294532775879
# [2025/01/03 20:17:06] ppocr DEBUG: cls num  : 39, elapsed : 0.26200127601623535
# [2025/01/03 20:17:10] ppocr DEBUG: rec_res num  : 39, elapsed : 4.215811252593994
# Processed 31.jpg -> 31.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\32.jpg
# [2025/01/03 20:17:11] ppocr DEBUG: dt_boxes num : 54, elapsed : 0.5907554626464844
# [2025/01/03 20:17:11] ppocr DEBUG: cls num  : 54, elapsed : 0.2676084041595459
# [2025/01/03 20:17:16] ppocr DEBUG: rec_res num  : 54, elapsed : 4.647024393081665
# Processed 32.jpg -> 32.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\33.jpg
# [2025/01/03 20:17:17] ppocr DEBUG: dt_boxes num : 36, elapsed : 0.5581858158111572
# [2025/01/03 20:17:17] ppocr DEBUG: cls num  : 36, elapsed : 0.1454017162322998
# [2025/01/03 20:17:19] ppocr DEBUG: rec_res num  : 36, elapsed : 2.498034715652466
# Processed 33.jpg -> 33.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\34.jpg
# [2025/01/03 20:17:20] ppocr DEBUG: dt_boxes num : 66, elapsed : 0.5370824337005615
# [2025/01/03 20:17:20] ppocr DEBUG: cls num  : 66, elapsed : 0.22999215126037598
# [2025/01/03 20:17:25] ppocr DEBUG: rec_res num  : 66, elapsed : 4.905406475067139
# Processed 34.jpg -> 34.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\35.jpg
# [2025/01/03 20:17:26] ppocr DEBUG: dt_boxes num : 49, elapsed : 0.7290496826171875
# [2025/01/03 20:17:26] ppocr DEBUG: cls num  : 49, elapsed : 0.2977919578552246
# [2025/01/03 20:17:30] ppocr DEBUG: rec_res num  : 49, elapsed : 3.53326416015625
# Processed 35.jpg -> 35.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\36.jpg
# [2025/01/03 20:17:31] ppocr DEBUG: dt_boxes num : 85, elapsed : 0.9085919857025146
# [2025/01/03 20:17:31] ppocr DEBUG: cls num  : 85, elapsed : 0.4890267848968506
# [2025/01/03 20:17:39] ppocr DEBUG: rec_res num  : 85, elapsed : 7.983063459396362
# Processed 36.jpg -> 36.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\37.jpg
# [2025/01/03 20:17:40] ppocr DEBUG: dt_boxes num : 57, elapsed : 0.7473762035369873
# [2025/01/03 20:17:41] ppocr DEBUG: cls num  : 57, elapsed : 0.8069360256195068
# [2025/01/03 20:17:46] ppocr DEBUG: rec_res num  : 57, elapsed : 5.426878452301025
# Processed 37.jpg -> 37.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\38.jpg
# [2025/01/03 20:17:47] ppocr DEBUG: dt_boxes num : 35, elapsed : 0.8092820644378662
# [2025/01/03 20:17:48] ppocr DEBUG: cls num  : 35, elapsed : 0.691913366317749
# [2025/01/03 20:17:51] ppocr DEBUG: rec_res num  : 35, elapsed : 3.432077646255493
# Processed 38.jpg -> 38.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\39.jpg
# [2025/01/03 20:17:52] ppocr DEBUG: dt_boxes num : 62, elapsed : 0.6680810451507568
# [2025/01/03 20:17:52] ppocr DEBUG: cls num  : 62, elapsed : 0.6463871002197266
# [2025/01/03 20:17:57] ppocr DEBUG: rec_res num  : 62, elapsed : 5.028733968734741
# Processed 39.jpg -> 39.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\4.jpg
# [2025/01/03 20:17:58] ppocr DEBUG: dt_boxes num : 55, elapsed : 0.8722245693206787
# [2025/01/03 20:17:59] ppocr DEBUG: cls num  : 55, elapsed : 0.5131208896636963
# [2025/01/03 20:18:05] ppocr DEBUG: rec_res num  : 55, elapsed : 5.761979579925537
# Processed 4.jpg -> 4.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\40.jpg
# [2025/01/03 20:18:05] ppocr DEBUG: dt_boxes num : 31, elapsed : 0.4838263988494873
# [2025/01/03 20:18:06] ppocr DEBUG: cls num  : 31, elapsed : 0.2693624496459961
# [2025/01/03 20:18:09] ppocr DEBUG: rec_res num  : 31, elapsed : 3.3157315254211426
# Processed 40.jpg -> 40.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\41.jpg
# Error processing 41.jpg: Error processing image C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\41.jpg: Failed to read image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\41.jpg
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\42.jpg
# [2025/01/03 20:18:09] ppocr DEBUG: dt_boxes num : 43, elapsed : 0.5450518131256104
# [2025/01/03 20:18:10] ppocr DEBUG: cls num  : 43, elapsed : 0.3027966022491455
# [2025/01/03 20:18:14] ppocr DEBUG: rec_res num  : 43, elapsed : 3.760157346725464
# Processed 42.jpg -> 42.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\43.jpg
# [2025/01/03 20:18:14] ppocr DEBUG: dt_boxes num : 15, elapsed : 0.43208861351013184
# [2025/01/03 20:18:14] ppocr DEBUG: cls num  : 15, elapsed : 0.3774700164794922
# [2025/01/03 20:18:16] ppocr DEBUG: rec_res num  : 15, elapsed : 1.4726803302764893
# Processed 43.jpg -> 43.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\44.jpg
# [2025/01/03 20:18:17] ppocr DEBUG: dt_boxes num : 30, elapsed : 0.6567230224609375
# [2025/01/03 20:18:17] ppocr DEBUG: cls num  : 30, elapsed : 0.14323735237121582
# [2025/01/03 20:18:20] ppocr DEBUG: rec_res num  : 30, elapsed : 2.923001289367676
# Processed 44.jpg -> 44.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\45.jpg
# [2025/01/03 20:18:20] ppocr DEBUG: dt_boxes num : 63, elapsed : 0.6681632995605469
# [2025/01/03 20:18:21] ppocr DEBUG: cls num  : 63, elapsed : 0.3551921844482422
# [2025/01/03 20:18:26] ppocr DEBUG: rec_res num  : 63, elapsed : 5.3531365394592285
# Processed 45.jpg -> 45.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\47.jpg
# [2025/01/03 20:18:27] ppocr DEBUG: dt_boxes num : 59, elapsed : 0.7183511257171631
# [2025/01/03 20:18:27] ppocr DEBUG: cls num  : 59, elapsed : 0.5582334995269775
# [2025/01/03 20:18:34] ppocr DEBUG: rec_res num  : 59, elapsed : 6.676385879516602
# Processed 47.jpg -> 47.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\48.jpg
# [2025/01/03 20:18:35] ppocr DEBUG: dt_boxes num : 60, elapsed : 0.734203577041626
# [2025/01/03 20:18:35] ppocr DEBUG: cls num  : 60, elapsed : 0.23328399658203125
# [2025/01/03 20:18:40] ppocr DEBUG: rec_res num  : 60, elapsed : 5.16884446144104
# Processed 48.jpg -> 48.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\49.jpg
# [2025/01/03 20:18:41] ppocr DEBUG: dt_boxes num : 98, elapsed : 0.8642899990081787
# [2025/01/03 20:18:42] ppocr DEBUG: cls num  : 98, elapsed : 0.7978355884552002
# [2025/01/03 20:18:50] ppocr DEBUG: rec_res num  : 98, elapsed : 7.590371370315552
# Processed 49.jpg -> 49.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\5.jpg
# [2025/01/03 20:18:50] ppocr DEBUG: dt_boxes num : 36, elapsed : 0.6635892391204834
# [2025/01/03 20:18:50] ppocr DEBUG: cls num  : 36, elapsed : 0.16644597053527832
# [2025/01/03 20:18:54] ppocr DEBUG: rec_res num  : 36, elapsed : 3.6861774921417236
# Processed 5.jpg -> 5.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\50.jpg
# [2025/01/03 20:18:55] ppocr DEBUG: dt_boxes num : 23, elapsed : 0.4636073112487793
# [2025/01/03 20:18:55] ppocr DEBUG: cls num  : 23, elapsed : 0.3670065402984619
# [2025/01/03 20:18:57] ppocr DEBUG: rec_res num  : 23, elapsed : 2.173658609390259
# Processed 50.jpg -> 50.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\51.jpg
# [2025/01/03 20:18:59] ppocr DEBUG: dt_boxes num : 40, elapsed : 1.2781524658203125
# [2025/01/03 20:18:59] ppocr DEBUG: cls num  : 40, elapsed : 0.6440000534057617
# [2025/01/03 20:19:04] ppocr DEBUG: rec_res num  : 40, elapsed : 4.975156545639038
# Processed 51.jpg -> 51.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\52.jpg
# [2025/01/03 20:19:05] ppocr DEBUG: dt_boxes num : 33, elapsed : 0.8065078258514404
# [2025/01/03 20:19:05] ppocr DEBUG: cls num  : 33, elapsed : 0.25765085220336914
# [2025/01/03 20:19:08] ppocr DEBUG: rec_res num  : 33, elapsed : 3.0845539569854736
# Processed 52.jpg -> 52.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\53.jpg
# [2025/01/03 20:19:09] ppocr DEBUG: dt_boxes num : 165, elapsed : 0.755690336227417
# [2025/01/03 20:19:10] ppocr DEBUG: cls num  : 165, elapsed : 0.8698480129241943
# [2025/01/03 20:19:22] ppocr DEBUG: rec_res num  : 165, elapsed : 11.66732406616211
# Processed 53.jpg -> 53.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\54.jpg
# [2025/01/03 20:19:22] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.31673526763916016
# [2025/01/03 20:19:22] ppocr DEBUG: cls num  : 2, elapsed : 0.11660313606262207
# [2025/01/03 20:19:23] ppocr DEBUG: rec_res num  : 2, elapsed : 0.33540844917297363
# Processed 54.jpg -> 54.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\55.jpg
# [2025/01/03 20:19:23] ppocr DEBUG: dt_boxes num : 52, elapsed : 0.5497725009918213
# [2025/01/03 20:19:23] ppocr DEBUG: cls num  : 52, elapsed : 0.36769604682922363
# [2025/01/03 20:19:28] ppocr DEBUG: rec_res num  : 52, elapsed : 4.481538772583008
# Processed 55.jpg -> 55.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\57.jpg
# [2025/01/03 20:19:29] ppocr DEBUG: dt_boxes num : 55, elapsed : 0.7523496150970459
# [2025/01/03 20:19:29] ppocr DEBUG: cls num  : 55, elapsed : 0.43235325813293457
# [2025/01/03 20:19:35] ppocr DEBUG: rec_res num  : 55, elapsed : 5.531243562698364
# Processed 57.jpg -> 57.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\58.jpg
# [2025/01/03 20:19:35] ppocr DEBUG: dt_boxes num : 35, elapsed : 0.3761422634124756
# [2025/01/03 20:19:35] ppocr DEBUG: cls num  : 35, elapsed : 0.33675622940063477
# [2025/01/03 20:19:38] ppocr DEBUG: rec_res num  : 35, elapsed : 2.817256450653076
# Processed 58.jpg -> 58.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\59.jpg
# [2025/01/03 20:19:39] ppocr DEBUG: dt_boxes num : 57, elapsed : 0.6433444023132324
# [2025/01/03 20:19:40] ppocr DEBUG: cls num  : 57, elapsed : 0.5387208461761475
# [2025/01/03 20:19:45] ppocr DEBUG: rec_res num  : 57, elapsed : 5.455448627471924
# Processed 59.jpg -> 59.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\60.jpg
# [2025/01/03 20:19:46] ppocr DEBUG: dt_boxes num : 102, elapsed : 0.6039993762969971
# [2025/01/03 20:19:46] ppocr DEBUG: cls num  : 102, elapsed : 0.5642120838165283
# [2025/01/03 20:19:55] ppocr DEBUG: rec_res num  : 102, elapsed : 8.745690107345581
# Processed 60.jpg -> 60.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\61.jpg
# [2025/01/03 20:19:55] ppocr DEBUG: dt_boxes num : 51, elapsed : 0.36530518531799316
# [2025/01/03 20:19:56] ppocr DEBUG: cls num  : 51, elapsed : 0.32236456871032715
# [2025/01/03 20:20:01] ppocr DEBUG: rec_res num  : 51, elapsed : 4.926819324493408
# Processed 61.jpg -> 61.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\62.jpg
# [2025/01/03 20:20:02] ppocr DEBUG: dt_boxes num : 74, elapsed : 0.8878815174102783
# [2025/01/03 20:20:03] ppocr DEBUG: cls num  : 74, elapsed : 1.061732530593872
# [2025/01/03 20:20:10] ppocr DEBUG: rec_res num  : 74, elapsed : 7.105810880661011
# Processed 62.jpg -> 62.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\63.jpg
# [2025/01/03 20:20:10] ppocr DEBUG: dt_boxes num : 31, elapsed : 0.5912959575653076
# [2025/01/03 20:20:11] ppocr DEBUG: cls num  : 31, elapsed : 0.3576371669769287
# [2025/01/03 20:20:14] ppocr DEBUG: rec_res num  : 31, elapsed : 3.535083532333374
# Processed 63.jpg -> 63.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\64.jpg
# [2025/01/03 20:20:15] ppocr DEBUG: dt_boxes num : 74, elapsed : 1.0204672813415527
# [2025/01/03 20:20:16] ppocr DEBUG: cls num  : 74, elapsed : 0.7551131248474121
# [2025/01/03 20:20:26] ppocr DEBUG: rec_res num  : 74, elapsed : 9.813612461090088
# Processed 64.jpg -> 64.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\65.jpg
# [2025/01/03 20:20:26] ppocr DEBUG: dt_boxes num : 57, elapsed : 0.5301938056945801
# [2025/01/03 20:20:27] ppocr DEBUG: cls num  : 57, elapsed : 0.4094424247741699
# [2025/01/03 20:20:31] ppocr DEBUG: rec_res num  : 57, elapsed : 4.542614221572876
# Processed 65.jpg -> 65.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\66.jpg
# [2025/01/03 20:20:32] ppocr DEBUG: dt_boxes num : 47, elapsed : 0.6819548606872559
# [2025/01/03 20:20:32] ppocr DEBUG: cls num  : 47, elapsed : 0.3135974407196045
# [2025/01/03 20:20:38] ppocr DEBUG: rec_res num  : 47, elapsed : 5.59549617767334
# Processed 66.jpg -> 66.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\67.jpg
# [2025/01/03 20:20:39] ppocr DEBUG: dt_boxes num : 33, elapsed : 0.5427837371826172
# [2025/01/03 20:20:39] ppocr DEBUG: cls num  : 33, elapsed : 0.5704770088195801
# [2025/01/03 20:20:43] ppocr DEBUG: rec_res num  : 33, elapsed : 3.581773042678833
# Processed 67.jpg -> 67.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\68.jpg
# [2025/01/03 20:20:44] ppocr DEBUG: dt_boxes num : 70, elapsed : 1.057920217514038
# [2025/01/03 20:20:45] ppocr DEBUG: cls num  : 70, elapsed : 0.585961103439331
# [2025/01/03 20:20:53] ppocr DEBUG: rec_res num  : 70, elapsed : 7.991886615753174
# Processed 68.jpg -> 68.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\69.jpg
# [2025/01/03 20:20:53] ppocr DEBUG: dt_boxes num : 102, elapsed : 0.8226377964019775
# [2025/01/03 20:20:54] ppocr DEBUG: cls num  : 102, elapsed : 0.7681031227111816
# [2025/01/03 20:21:04] ppocr DEBUG: rec_res num  : 102, elapsed : 10.249392986297607
# Processed 69.jpg -> 69.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\7.jpg
# [2025/01/03 20:21:05] ppocr DEBUG: dt_boxes num : 36, elapsed : 0.9752757549285889
# [2025/01/03 20:21:06] ppocr DEBUG: cls num  : 36, elapsed : 0.14742612838745117
# [2025/01/03 20:21:09] ppocr DEBUG: rec_res num  : 36, elapsed : 3.5929617881774902
# Processed 7.jpg -> 7.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\70.jpg
# [2025/01/03 20:21:10] ppocr DEBUG: dt_boxes num : 62, elapsed : 0.469188928604126
# [2025/01/03 20:21:10] ppocr DEBUG: cls num  : 62, elapsed : 0.6263790130615234
# [2025/01/03 20:21:17] ppocr DEBUG: rec_res num  : 62, elapsed : 7.184295177459717
# Processed 70.jpg -> 70.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\71.jpg
# [2025/01/03 20:21:18] ppocr DEBUG: dt_boxes num : 54, elapsed : 0.6752374172210693
# [2025/01/03 20:21:19] ppocr DEBUG: cls num  : 54, elapsed : 0.3968672752380371
# [2025/01/03 20:21:24] ppocr DEBUG: rec_res num  : 54, elapsed : 5.791396141052246
# Processed 71.jpg -> 71.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\72.jpg
# [2025/01/03 20:21:26] ppocr DEBUG: dt_boxes num : 29, elapsed : 1.3322041034698486
# [2025/01/03 20:21:26] ppocr DEBUG: cls num  : 29, elapsed : 0.6329286098480225
# [2025/01/03 20:21:31] ppocr DEBUG: rec_res num  : 29, elapsed : 4.828414440155029
# Processed 72.jpg -> 72.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\73.jpg
# [2025/01/03 20:21:32] ppocr DEBUG: dt_boxes num : 82, elapsed : 0.5249514579772949
# [2025/01/03 20:21:33] ppocr DEBUG: cls num  : 82, elapsed : 0.9244692325592041
# [2025/01/03 20:21:42] ppocr DEBUG: rec_res num  : 82, elapsed : 9.308764457702637
# Processed 73.jpg -> 73.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\74.jpg
# [2025/01/03 20:21:43] ppocr DEBUG: dt_boxes num : 54, elapsed : 1.1801331043243408
# [2025/01/03 20:21:44] ppocr DEBUG: cls num  : 54, elapsed : 0.44131946563720703
# [2025/01/03 20:21:49] ppocr DEBUG: rec_res num  : 54, elapsed : 5.4907801151275635
# Processed 74.jpg -> 74.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\75.jpg
# [2025/01/03 20:21:50] ppocr DEBUG: dt_boxes num : 37, elapsed : 0.7043492794036865
# [2025/01/03 20:21:50] ppocr DEBUG: cls num  : 37, elapsed : 0.40447497367858887
# [2025/01/03 20:21:54] ppocr DEBUG: rec_res num  : 37, elapsed : 3.742061138153076
# Processed 75.jpg -> 75.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\76.jpg
# [2025/01/03 20:21:55] ppocr DEBUG: dt_boxes num : 41, elapsed : 0.855600118637085
# [2025/01/03 20:21:56] ppocr DEBUG: cls num  : 41, elapsed : 0.4058394432067871
# [2025/01/03 20:22:01] ppocr DEBUG: rec_res num  : 41, elapsed : 5.098039627075195
# Processed 76.jpg -> 76.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\77.jpg
# [2025/01/03 20:22:01] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.5272841453552246
# [2025/01/03 20:22:02] ppocr DEBUG: cls num  : 2, elapsed : 0.3866286277770996
# [2025/01/03 20:22:02] ppocr DEBUG: rec_res num  : 2, elapsed : 0.6216413974761963
# Processed 77.jpg -> 77.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\78.jpg
# [2025/01/03 20:22:03] ppocr DEBUG: dt_boxes num : 42, elapsed : 1.1407544612884521
# [2025/01/03 20:22:04] ppocr DEBUG: cls num  : 42, elapsed : 0.3037145137786865
# [2025/01/03 20:22:09] ppocr DEBUG: rec_res num  : 42, elapsed : 5.037389278411865
# Processed 78.jpg -> 78.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\79.jpg
# [2025/01/03 20:22:10] ppocr DEBUG: dt_boxes num : 66, elapsed : 1.3054871559143066
# [2025/01/03 20:22:11] ppocr DEBUG: cls num  : 66, elapsed : 0.7797722816467285
# [2025/01/03 20:22:18] ppocr DEBUG: rec_res num  : 66, elapsed : 6.613685846328735
# Processed 79.jpg -> 79.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\8.jpg
# [2025/01/03 20:22:18] ppocr DEBUG: dt_boxes num : 107, elapsed : 0.7537765502929688
# [2025/01/03 20:22:19] ppocr DEBUG: cls num  : 107, elapsed : 0.6852078437805176
# [2025/01/03 20:22:28] ppocr DEBUG: rec_res num  : 107, elapsed : 8.514798164367676
# Processed 8.jpg -> 8.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\80.jpg
# [2025/01/03 20:22:28] ppocr DEBUG: dt_boxes num : 37, elapsed : 0.17863178253173828
# [2025/01/03 20:22:28] ppocr DEBUG: cls num  : 37, elapsed : 0.5547618865966797
# [2025/01/03 20:22:32] ppocr DEBUG: rec_res num  : 37, elapsed : 4.022587060928345
# Processed 80.jpg -> 80.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\81.jpg
# [2025/01/03 20:22:33] ppocr DEBUG: dt_boxes num : 49, elapsed : 0.830862283706665
# [2025/01/03 20:22:34] ppocr DEBUG: cls num  : 49, elapsed : 0.3605222702026367
# [2025/01/03 20:22:39] ppocr DEBUG: rec_res num  : 49, elapsed : 5.205404996871948
# Processed 81.jpg -> 81.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\82.jpg
# [2025/01/03 20:22:40] ppocr DEBUG: dt_boxes num : 40, elapsed : 1.1493499279022217
# [2025/01/03 20:22:41] ppocr DEBUG: cls num  : 40, elapsed : 0.40281009674072266
# [2025/01/03 20:22:45] ppocr DEBUG: rec_res num  : 40, elapsed : 4.352582216262817
# Processed 82.jpg -> 82.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\83.jpg
# [2025/01/03 20:22:45] ppocr DEBUG: dt_boxes num : 39, elapsed : 0.44582271575927734
# [2025/01/03 20:22:46] ppocr DEBUG: cls num  : 39, elapsed : 0.46527981758117676
# [2025/01/03 20:22:49] ppocr DEBUG: rec_res num  : 39, elapsed : 3.1697256565093994
# Processed 83.jpg -> 83.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\84.jpg
# [2025/01/03 20:22:50] ppocr DEBUG: dt_boxes num : 104, elapsed : 0.8141279220581055
# [2025/01/03 20:22:51] ppocr DEBUG: cls num  : 104, elapsed : 0.8932113647460938
# [2025/01/03 20:23:00] ppocr DEBUG: rec_res num  : 104, elapsed : 9.085147857666016
# Processed 84.jpg -> 84.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\85.jpg
# [2025/01/03 20:23:01] ppocr DEBUG: dt_boxes num : 81, elapsed : 0.8351936340332031
# [2025/01/03 20:23:01] ppocr DEBUG: cls num  : 81, elapsed : 0.5543975830078125
# [2025/01/03 20:23:09] ppocr DEBUG: rec_res num  : 81, elapsed : 7.296523094177246
# Processed 85.jpg -> 85.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\86.jpg
# [2025/01/03 20:23:10] ppocr DEBUG: dt_boxes num : 74, elapsed : 0.7986674308776855
# [2025/01/03 20:23:10] ppocr DEBUG: cls num  : 74, elapsed : 0.803234338760376
# [2025/01/03 20:23:17] ppocr DEBUG: rec_res num  : 74, elapsed : 6.840641498565674
# Processed 86.jpg -> 86.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\87.jpg
# [2025/01/03 20:23:18] ppocr DEBUG: dt_boxes num : 63, elapsed : 0.9239208698272705
# [2025/01/03 20:23:19] ppocr DEBUG: cls num  : 63, elapsed : 0.7908535003662109
# [2025/01/03 20:23:26] ppocr DEBUG: rec_res num  : 63, elapsed : 6.830458402633667
# Processed 87.jpg -> 87.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\88.jpg
# [2025/01/03 20:23:27] ppocr DEBUG: dt_boxes num : 102, elapsed : 0.7753674983978271
# [2025/01/03 20:23:27] ppocr DEBUG: cls num  : 102, elapsed : 0.5831289291381836
# [2025/01/03 20:23:37] ppocr DEBUG: rec_res num  : 102, elapsed : 9.331690788269043
# Processed 88.jpg -> 88.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\89.jpg
# [2025/01/03 20:23:37] ppocr DEBUG: dt_boxes num : 82, elapsed : 0.7918219566345215
# [2025/01/03 20:23:38] ppocr DEBUG: cls num  : 82, elapsed : 0.6253206729888916
# [2025/01/03 20:23:46] ppocr DEBUG: rec_res num  : 82, elapsed : 7.580497741699219
# Processed 89.jpg -> 89.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\9.jpg
# [2025/01/03 20:23:46] ppocr DEBUG: dt_boxes num : 98, elapsed : 0.7727012634277344
# [2025/01/03 20:23:47] ppocr DEBUG: cls num  : 98, elapsed : 0.7500782012939453
# [2025/01/03 20:23:57] ppocr DEBUG: rec_res num  : 98, elapsed : 9.555002927780151
# Processed 9.jpg -> 9.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\90.jpg
# [2025/01/03 20:23:58] ppocr DEBUG: dt_boxes num : 36, elapsed : 0.8432884216308594
# [2025/01/03 20:23:58] ppocr DEBUG: cls num  : 36, elapsed : 0.3827531337738037
# [2025/01/03 20:24:03] ppocr DEBUG: rec_res num  : 36, elapsed : 4.5005974769592285
# Processed 90.jpg -> 90.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\91.jpg
# [2025/01/03 20:24:03] ppocr DEBUG: dt_boxes num : 29, elapsed : 0.7987885475158691
# [2025/01/03 20:24:04] ppocr DEBUG: cls num  : 29, elapsed : 0.4257326126098633
# [2025/01/03 20:24:07] ppocr DEBUG: rec_res num  : 29, elapsed : 2.9676523208618164
# Processed 91.jpg -> 91.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\92.jpg
# [2025/01/03 20:24:07] ppocr DEBUG: dt_boxes num : 23, elapsed : 0.17512989044189453
# [2025/01/03 20:24:07] ppocr DEBUG: cls num  : 23, elapsed : 0.1568012237548828
# [2025/01/03 20:24:09] ppocr DEBUG: rec_res num  : 23, elapsed : 2.2048637866973877
# Processed 92.jpg -> 92.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\93.jpg
# [2025/01/03 20:24:10] ppocr DEBUG: dt_boxes num : 45, elapsed : 0.9754598140716553
# [2025/01/03 20:24:11] ppocr DEBUG: cls num  : 45, elapsed : 0.5695228576660156
# [2025/01/03 20:24:15] ppocr DEBUG: rec_res num  : 45, elapsed : 3.9463179111480713
# Processed 93.jpg -> 93.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\95.jpg
# [2025/01/03 20:24:16] ppocr DEBUG: dt_boxes num : 50, elapsed : 0.9991121292114258
# [2025/01/03 20:24:17] ppocr DEBUG: cls num  : 50, elapsed : 0.6235527992248535
# [2025/01/03 20:24:21] ppocr DEBUG: rec_res num  : 50, elapsed : 4.654401540756226
# Processed 95.jpg -> 95.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\96.jpg
# [2025/01/03 20:24:22] ppocr DEBUG: dt_boxes num : 39, elapsed : 0.6173510551452637
# [2025/01/03 20:24:22] ppocr DEBUG: cls num  : 39, elapsed : 0.3382530212402344
# [2025/01/03 20:24:26] ppocr DEBUG: rec_res num  : 39, elapsed : 3.889207363128662
# Processed 96.jpg -> 96.txt
# Processing image: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\extracted_text\64.txt
#
# File: 65.jpg
# Confidence: 0.99
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\extracted_text\65.txt
#
# File: 66.jpg
# Confidence: 0.96
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\extracted_text\66.txt
#
# File: 67.jpg
# Confidence: 0.85
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\extracted_text\67.txt
#
# File: 68.jpg
# Confidence: 0.96
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\extracted_text\68.txt
#
# File: 69.jpg
# Confidence: 0.94
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\extracted_text\69.txt
#
# File: 7.jpg
# Confidence: 0.85
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\extracted_text\7.txt
#
# File: 70.jpg
# Confidence: 0.96
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\extracted_text\70.txt
#
# File: 71.jpg
# Confidence: 0.98
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\extracted_text\71.txt
#
# File: 72.jpg
# Confidence: 0.98
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\extracted_text\72.txt
#
# File: 73.jpg
# Confidence: 0.91
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\extracted_text\73.txt
#
# File: 74.jpg
# Confidence: 0.95
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\extracted_text\74.txt
#
# File: 75.jpg
# Confidence: 0.98
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\extracted_text\75.txt
#
# File: 76.jpg
# Confidence: 0.97
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\extracted_text\76.txt
#
# File: 77.jpg
# Confidence: 0.97
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\extracted_text\77.txt
#
# File: 78.jpg
# Confidence: 0.98
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\extracted_text\78.txt
#
# File: 79.jpg
# Confidence: 0.97
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\extracted_text\79.txt
#
# File: 8.jpg
# Confidence: 0.97
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\extracted_text\8.txt
#
# File: 80.jpg
# Confidence: 0.98
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\extracted_text\80.txt
#
# File: 81.jpg
# Confidence: 0.98
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\extracted_text\81.txt
#
# File: 82.jpg
# Confidence: 0.98
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\extracted_text\82.txt
#
# File: 83.jpg
# Confidence: 0.85
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\extracted_text\83.txt
#
# File: 84.jpg
# Confidence: 0.96
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\extracted_text\84.txt
#
# File: 85.jpg
# Confidence: 0.98
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\extracted_text\85.txt
#
# File: 86.jpg
# Confidence: 0.98
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\extracted_text\86.txt
#
# File: 87.jpg
# Confidence: 0.95
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\extracted_text\87.txt
#
# File: 88.jpg
# Confidence: 0.94
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\extracted_text\88.txt
#
# File: 89.jpg
# Confidence: 0.98
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\extracted_text\89.txt
#
# File: 9.jpg
# Confidence: 0.90
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\extracted_text\9.txt
#
# File: 90.jpg
# Confidence: 0.99
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\extracted_text\90.txt
#
# File: 91.jpg
# Confidence: 0.98
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\extracted_text\91.txt
#
# File: 92.jpg
# Confidence: 1.00
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\extracted_text\92.txt
#
# File: 93.jpg
# Confidence: 0.98
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\extracted_text\93.txt
#
# File: 95.jpg
# Confidence: 0.98
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\extracted_text\95.txt
#
# File: 96.jpg
# Confidence: 0.97
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\extracted_text\96.txt
#
# File: 97.jpg
# Confidence: 0.96
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\extracted_text\97.txt
#
# File: 98.jpg
# Confidence: 0.92
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\extracted_text\98.txt
#
# File: 99.jpg
# Confidence: 0.99
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\Salary Slip\extracted_text\99.txt

# %%
def process_pdfs_in_folder(folder_path: str, output_dir: str = None) -> List[Dict]:
    """
    Process all PDFs (both searchable and scanned) in a folder and its subfolders
    
    Args:
        folder_path: Path to folder containing PDFs
        output_dir: Directory to save extracted text files (defaults to 'extracted_text' in folder_path)
    
    Returns:
        List[Dict]: List of results containing file info and extracted text
    """
    # Set up output directory
    if output_dir is None:
        output_dir = os.path.join(folder_path, 'extracted_text')
    os.makedirs(output_dir, exist_ok=True)
    
    results = []
    # Walk through all subdirectories
    for root, _, files in os.walk(folder_path):
        for file in files:
            if file.lower().endswith('.pdf'):
                try:
                    # Get full file path
                    file_path = os.path.join(root, file)
                    
                    # Create relative path structure in output directory
                    rel_path = os.path.relpath(root, folder_path)
                    output_subdir = os.path.join(output_dir, rel_path)
                    os.makedirs(output_subdir, exist_ok=True)
                    
                    # Process PDF
                    print(f"Processing: {file_path}")
                    result = reader.read_document(file_path)
                    
                    # Create output filename
                    output_filename = os.path.splitext(file)[0] + '.txt'
                    output_path = os.path.join(output_subdir, output_filename)
                    
                    # Save extracted text to file
                    with open(output_path, 'w', encoding='utf-8') as f:
                        f.write(result['text'])
                    
                    results.append({
                        'file': file_path,
                        'num_pages': result['num_pages'],
                        'text': result['text'],
                        'output_path': output_path
                    })
                    
                    print(f"Saved to: {output_path}")
                    
                except Exception as e:
                    print(f"Error processing {file}: {str(e)}")
    
    return results

# Example usage
reader = DocumentReader()
folder_results = process_pdfs_in_folder(r'C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders')

# Print summary
print("\nProcessing Summary:")
print(f"Total PDFs processed: {len(folder_results)}")
for result in folder_results:
    print(f"\nFile: {result['file']}")
    print(f"Pages: {result['num_pages']}")
    print(f"Output: {result['output_path']}")
# Out:
# [2025/01/03 20:53:22] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\ayesha.amjad/.paddleocr/whl\\det\\en\\en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\ayesha.amjad/.paddleocr/whl\\rec\\en\\en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='c:\\Users\\ayesha.amjad\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\paddleocr\\ppocr\\utils\\en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='C:\\Users\\ayesha.amjad/.paddleocr/whl\\cls\\ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\2_PURESOURCE CORDOVA PO.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\2_PURESOURCE CORDOVA PO.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\2_PURESOURCE EAST 3RD PO.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\2_PURESOURCE EAST 3RD PO.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\2_PURESOURCE EAST 3RDPO.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\2_PURESOURCE EAST 3RDPO.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\2_PURESOURCE LIQ CORDOVA PO.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\2_PURESOURCE LIQ CORDOVA PO.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\2_PURESOURCE LIQ EAST 3RD PO.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\2_PURESOURCE LIQ EAST 3RD PO.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\Borgwarner_PurchaseOrder.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\Borgwarner_PurchaseOrder.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\Camfil_PurchaseOrders_1.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\Camfil_PurchaseOrders_1.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\Camfil_PurchaseOrders_2.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\Camfil_PurchaseOrders_2.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\Camfil_PurchaseOrders_3.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\Camfil_PurchaseOrders_3.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\Camfil_PurchaseOrders_4.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\Camfil_PurchaseOrders_4.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\Camfil_PurchaseOrders_5.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\Camfil_PurchaseOrders_5.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\Camfil_PurchaseOrders_6.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\Camfil_PurchaseOrders_6.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\CandRMetals_PurchaseOrders_1.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\CandRMetals_PurchaseOrders_1.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\CandRMetals_PurchaseOrders_10.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\CandRMetals_PurchaseOrders_10.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\CandRMetals_PurchaseOrders_11.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\CandRMetals_PurchaseOrders_11.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\CandRMetals_PurchaseOrders_12.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\CandRMetals_PurchaseOrders_12.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\CandRMetals_PurchaseOrders_13.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\CandRMetals_PurchaseOrders_13.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\CandRMetals_PurchaseOrders_14.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\CandRMetals_PurchaseOrders_14.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\CandRMetals_PurchaseOrders_15.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\CandRMetals_PurchaseOrders_15.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\CandRMetals_PurchaseOrders_16.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\CandRMetals_PurchaseOrders_16.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\CandRMetals_PurchaseOrders_17.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\CandRMetals_PurchaseOrders_17.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\CandRMetals_PurchaseOrders_18.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\CandRMetals_PurchaseOrders_18.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\CandRMetals_PurchaseOrders_19.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\CandRMetals_PurchaseOrders_19.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\CandRMetals_PurchaseOrders_2.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\CandRMetals_PurchaseOrders_2.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\CandRMetals_PurchaseOrders_20.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\CandRMetals_PurchaseOrders_20.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\CandRMetals_PurchaseOrders_3.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\CandRMetals_PurchaseOrders_3.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\CandRMetals_PurchaseOrders_4.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\CandRMetals_PurchaseOrders_4.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\CandRMetals_PurchaseOrders_5.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\CandRMetals_PurchaseOrders_5.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\CandRMetals_PurchaseOrders_6.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\CandRMetals_PurchaseOrders_6.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\CandRMetals_PurchaseOrders_7.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\CandRMetals_PurchaseOrders_7.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\CandRMetals_PurchaseOrders_8.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\CandRMetals_PurchaseOrders_8.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\CandRMetals_PurchaseOrders_9.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\CandRMetals_PurchaseOrders_9.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\Ciena_PurchaseOrder.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\Ciena_PurchaseOrder.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\ClassicalMusicalDistributor_PurchaseOrders_1.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\ClassicalMusicalDistributor_PurchaseOrders_1.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\ClassicalMusicalDistributor_PurchaseOrders_2.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\ClassicalMusicalDistributor_PurchaseOrders_2.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\ECOFLOR_PurchaseOrder.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\ECOFLOR_PurchaseOrder.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\EMTInternational_PurchaseOrder.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\EMTInternational_PurchaseOrder.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\Foodlink - Ahold - Giant Carlisle .pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\Foodlink - Ahold - Giant Carlisle .txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\Foodlink - Ahold - Stop and Shop .pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\Foodlink - Ahold - Stop and Shop .txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\Foodlink - C&S Baldwin - Foodlink - .pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\Foodlink - C&S Baldwin - Foodlink - .txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\GoodnessMeorders.psource.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\GoodnessMeorders.psource.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\HealthyPlanetPurchase Order PO593426.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\HealthyPlanetPurchase Order PO593426.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\HealthyPlanetPurchase Order PO641431.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\HealthyPlanetPurchase Order PO641431.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\HealthyPlanetPurchase Order PO641431_4AAJxg.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\HealthyPlanetPurchase Order PO641431_4AAJxg.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\HealthyPlanetPurchase Order PO641433.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\HealthyPlanetPurchase Order PO641433.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\HealthyPlanetPurchase Order PO641433_4AAJxg.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\HealthyPlanetPurchase Order PO641433_4AAJxg.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\HealthyPlanetPurchase Order PO641435.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\HealthyPlanetPurchase Order PO641435.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\HealthyPlanetPurchase Order PO641435_4AAJxg.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\HealthyPlanetPurchase Order PO641435_4AAJxg.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\HealthyPlanetPurchase Order PO641437.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\HealthyPlanetPurchase Order PO641437.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\HealthyPlanetPurchase Order PO641442.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\HealthyPlanetPurchase Order PO641442.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\HealthyPlanetPurchase Order PO641444.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\HealthyPlanetPurchase Order PO641444.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\HealthyPlanetPurchase Order PO641449.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\HealthyPlanetPurchase Order PO641449.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\HealthyPlanetPurchase Order PO641450.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\HealthyPlanetPurchase Order PO641450.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\HealthyPlanetPurchase Order PO641451.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\HealthyPlanetPurchase Order PO641451.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\HealthyPlanetPurchase Order PO641451_4AAJxj.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\HealthyPlanetPurchase Order PO641451_4AAJxj.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\HealthyPlanetPurchase Order PO641451_4AAJxm.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\HealthyPlanetPurchase Order PO641451_4AAJxm.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\HealthyPlanetPurchase Order PO642125.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\HealthyPlanetPurchase Order PO642125.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\HealthyPlanetPurchase Order PO642125_4AAJxj.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\HealthyPlanetPurchase Order PO642125_4AAJxj.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\HealthyPlanetPurchase Order PO642125_4AAJxm.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\HealthyPlanetPurchase Order PO642125_4AAJxm.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\Inari New Listings Aug 31 2021.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\Inari New Listings Aug 31 2021.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\InvoiceWithTableBoundary2_PO_Cienna_1_PO_Cienna_2_PO_Cienna_3_PO_Cienna_4.pdf
# Processing as searchable PDF...
# Saved to: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\InvoiceWithTableBoundary2_PO_Cienna_1_PO_Cienna_2_PO_Cienna_3_PO_Cienna_4.txt
# Processing: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders
txt
#
# File: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\QSYSPRT547030000010_EAAAHD..pdf
# Pages: 2
# Output: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\QSYSPRT547030000010_EAAAHD..txt
#
# File: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\QSYSPRT548020000003_EAAAHF..pdf
# Pages: 3
# Output: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\QSYSPRT548020000003_EAAAHF..txt
#
# File: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\QSYSPRT548022000001_EAAAHG..pdf
# Pages: 3
# Output: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\QSYSPRT548022000001_EAAAHG..txt
#
# File: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\QSYSPRT548022000001_EAAAHH..pdf
# Pages: 3
# Output: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\QSYSPRT548022000001_EAAAHH..txt
#
# File: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\QSYSPRT548022000001_EAAAHI..pdf
# Pages: 3
# Output: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\QSYSPRT548022000001_EAAAHI..txt
#
# File: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\QSYSPRT548740000004_EAAAHJ..pdf
# Pages: 3
# Output: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\QSYSPRT548740000004_EAAAHJ..txt
#
# File: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\QSYSPRT548740000005_EAAAHK..pdf
# Pages: 4
# Output: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\QSYSPRT548740000005_EAAAHK..txt
#
# File: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\QSYSPRT549536000030_EAAAHL..pdf
# Pages: 4
# Output: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\QSYSPRT549536000030_EAAAHL..txt
#
# File: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\QSYSPRT549536000030_EAAAHO..pdf
# Pages: 4
# Output: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\QSYSPRT549536000030_EAAAHO..txt
#
# File: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\QSYSPRT549536000031_EAAAHM..pdf
# Pages: 2
# Output: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\QSYSPRT549536000031_EAAAHM..txt
#
# File: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\QSYSPRT549536000031_EAAAHN..pdf
# Pages: 2
# Output: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\QSYSPRT549536000031_EAAAHN..txt
#
# File: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\QSYSPRT550721000001_EAAAHT..pdf
# Pages: 4
# Output: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\QSYSPRT550721000001_EAAAHT..txt
#
# File: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\QTF15388520220401142039ID434458.pdf
# Pages: 2
# Output: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\QTF15388520220401142039ID434458.txt
#
# File: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\Quidel 294741 delivery ticket more detail.pdf
# Pages: 322
# Output: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\Quidel 294741 delivery ticket more detail.txt
#
# File: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\Safeway464584.pdf
# Pages: 1
# Output: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\Safeway464584.txt
#
# File: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\Sample Purchase Order in PDF.pdf
# Pages: 1
# Output: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\Sample Purchase Order in PDF.txt
#
# File: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\Sample4.pdf
# Pages: 2
# Output: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\Sample4.txt
#
# File: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\SampleAutoGenerateTable (2).pdf
# Pages: 1
# Output: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\SampleAutoGenerateTable (2).txt
#
# File: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\SampleAutoGenerateTable.pdf
# Pages: 1
# Output: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\SampleAutoGenerateTable.txt
#
# File: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\SampleTable.pdf
# Pages: 1
# Output: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\SampleTable.txt
#
# File: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\sample_po_+en.pdf
# Pages: 2
# Output: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\sample_po_+en.txt
#
# File: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\SEQ057170.pdf
# Pages: 4
# Output: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\SEQ057170.txt
#
# File: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\Shipp Belting Purchase Order 53671.pdf
# Pages: 1
# Output: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\Shipp Belting Purchase Order 53671.txt
#
# File: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\Sinopower PO - 3306-1704014 SM3411NKQAC-TRG-Revised (3 Lot code) - Copy.pdf
# Pages: 1
# Output: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\Sinopower PO - 3306-1704014 SM3411NKQAC-TRG-Revised (3 Lot code) - Copy.txt
#
# File: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\SLED_PO_Template.pdf
# Pages: 1
# Output: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\SLED_PO_Template.txt
#
# File: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\SLED_PO_Template_updated.pdf
# Pages: 1
# Output: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\SLED_PO_Template_updated.txt
#
# File: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\Stihl Southwest PO for Report Miner_signed.pdf
# Pages: 1
# Output: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\Stihl Southwest PO for Report Miner_signed.txt
#
# File: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\STU4500479883 NTT EAST.pdf
# Pages: 1
# Output: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\STU4500479883 NTT EAST.txt
#
# File: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\STU4500487640 NTT WEST.pdf
# Pages: 1
# Output: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\STU4500487640 NTT WEST.txt
#
# File: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\STU4500493582.pdf
# Pages: 1
# Output: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\STU4500493582.txt
#
# File: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\TabularData.pdf
# Pages: 1
# Output: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\TabularData.txt
#
# File: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\TaylorCommunications_PurchaseOrders_1.pdf
# Pages: 1
# Output: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\TaylorCommunications_PurchaseOrders_1.txt
#
# File: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\TaylorCommunications_PurchaseOrders_2.pdf
# Pages: 1
# Output: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\TaylorCommunications_PurchaseOrders_2.txt
#
# File: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\TaylorCommunications_PurchaseOrders_3.pdf
# Pages: 1
# Output: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\TaylorCommunications_PurchaseOrders_3.txt
#
# File: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\TaylorCommunications_PurchaseOrders_4.pdf
# Pages: 1
# Output: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\TaylorCommunications_PurchaseOrders_4.txt
#
# File: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\tdext440111107 - 2023-04-05T123617.471.pdf
# Pages: 1
# Output: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\tdext440111107 - 2023-04-05T123617.471.txt
#
# File: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\VirginMedia_PurchaseOrder.pdf
# Pages: 1
# Output: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\VirginMedia_PurchaseOrder.txt
#
# File: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\Whole Foods Market Order.pdf
# Pages: 1
# Output: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\Whole Foods Market Order.txt
#
# File: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\Whole Foods Market Order2.pdf
# Pages: 2
# Output: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\Whole Foods Market Order2.txt
#
# File: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\Whole Foods Market Order3.pdf
# Pages: 1
# Output: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\Whole Foods Market Order3.txt
#
# File: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\Whole Foods Market OrderColored.pdf
# Pages: 1
# Output: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\Whole Foods Market OrderColored.txt
#
# File: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\XML001-e.PDF
# Pages: 1
# Output: C:\Users\ayesha.amjad\OneDrive - Astera Software\Documents\GitHub\Unstructured-Data-Extraction\data\PurchaseOrders\extracted_text\.\XML001-e.txt
